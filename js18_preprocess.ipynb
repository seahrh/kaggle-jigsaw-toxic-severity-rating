# %%
import os
import numpy as np
import pandas as pd
import torch
from sentence_transformers import SentenceTransformer
from scipy.stats import rankdata
from tqdm import tqdm
import scml

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda
# NVIDIA GeForce GTX 1060 6GB
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB

# %%
percentiles=[.01, .05, .1, .2, .3, .4, .5, .6, .7, .8, .9, .95, .99]
os.environ["TOKENIZERS_PARALLELISM"] = "false"
pd.set_option("use_inf_as_na", True)
pd.set_option("max_info_columns", 9999)
pd.set_option("display.max_columns", 9999)
pd.set_option("display.max_rows", 9999)
pd.set_option('max_colwidth', 9999)
tqdm.pandas()

# %%
# %%time
df = pd.read_csv("input/js18/train.csv", engine="c", low_memory=False)
df.drop(columns=["id"], inplace=True)
cols = ["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]
df[cols] = df[cols].astype(np.int8) 
df["label_sum"] = df["toxic"] + df["severe_toxic"] + df["obscene"] + df["threat"] + df["insult"] + df["identity_hate"]
df.drop(index=df[df.label_sum == 0].index, inplace=True)
df.drop(columns=["label_sum"], inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16225 entries, 6 to 159554
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   comment_text   16225 non-null  object
#  1   toxic          16225 non-null  int8
#  2   severe_toxic   16225 non-null  int8
#  3   obscene        16225 non-null  int8
#  4   threat         16225 non-null  int8
#  5   insult         16225 non-null  int8
#  6   identity_hate  16225 non-null  int8
# dtypes: int8(6), object(1)
# memory usage: 348.6+ KB
# Wall time: 967 ms

# %%
scml.find_missing_values(df)
# Out:
#                Total  Percent    Type
# comment_text       0      0.0  object
# toxic              0      0.0    int8
# severe_toxic       0      0.0    int8
# obscene            0      0.0    int8
# threat             0      0.0    int8
# insult             0      0.0    int8
# identity_hate      0      0.0    int8

# %%
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               comment_text  \
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             COCKSUCKER BEFORE YOU PISS AROUND ON MY WORK
# 12                                                                                                                                                                                                                                                                                                                                                     Hey... what is it..\n@ | talk .\nWhat is it... an exclusive group of some WP TALIBANS...who are good at destroying, self-appointed purist who GANG UP any one who asks them questions abt their ANTI-SOCIAL and DESTRUCTIVE (non)-contribution at WP?\n\nAsk Sityush to clean up his behavior than issue me nonsensical warnings...
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Bye! \n\nDon't look, come or think of comming back! Tosser.
# 42  You are gay or antisemmitian? \n\nArchangel WHite Tiger\n\nMeow! Greetingshhh!\n\nUh, there are two ways, why you do erased my comment about WW2, that holocaust was brutally slaying of Jews and not gays/Gypsys/Slavs/anyone...\n\n1 - If you are anti-semitian, than shave your head bald and go to the skinhead meetings!\n\n2 - If you doubt words of the Bible, that homosexuality is a deadly sin, make a pentagram tatoo on your forehead go to the satanistic masses with your gay pals!\n\n3 - First and last warning, you fucking gay - I won't appreciate if any more nazi shwain would write in my page! I don't wish to talk to you anymore!\n\nBeware of the Dark Side!
# 43                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                FUCK YOUR FILTHY MOTHER IN THE ASS, DRY!
#
#     toxic  severe_toxic  obscene  threat  insult  identity_hate
# 6       1             1        1       0       1              0
# 12      1             0        0       0       0              0
# 16      1             0        0       0       0              0
# 42      1             0        1       0       1              1
# 43      1             0        1       0       1              0

# %% [markdown]
# # Severity rating label

# %%
df[cols].value_counts(normalize=True)
# Out:
# toxic  severe_toxic  obscene  threat  insult  identity_hate
# 1      0             0        0       0       0                0.349214
#                      1        0       1       0                0.234206
#                                       0       0                0.108351
#                      0        0       1       0                0.074884
#        1             1        0       1       0                0.060955
#        0             1        0       1       1                0.038089
# 0      0             1        0       0       0                0.019538
#                      0        0       1       0                0.018552
# 1      1             1        0       1       1                0.016333
# 0      0             1        0       1       0                0.011156
# 1      1             1        0       0       0                0.009738
#        0             0        0       0       1                0.008382
#                                       1       1                0.008259
#                      1        1       1       0                0.008074
#                      0        1       0       0                0.006965
#        1             1        1       1       0                0.003945
#        0             1        1       1       1                0.003451
# 0      0             0        0       0       1                0.003328
# 1      1             0        0       0       0                0.002527
#        0             1        0       0       1                0.002157
#        1             1        1       1       1                0.001911
# 0      0             0        0       1       1                0.001726
#                               1       0       0                0.001356
#                      1        0       1       1                0.001109
# 1      0             0        1       1       0                0.000986
#        1             0        0       1       0                0.000863
#                               1       0       0                0.000678
#        0             1        1       0       0                0.000678
#        1             0        0       1       1                0.000431
#        0             0        1       0       1                0.000431
#        1             1        0       0       1                0.000370
#                               1       0       0                0.000247
#                      0        0       0       1                0.000185
# 0      0             1        0       0       1                0.000185
#                      0        1       1       0                0.000185
# 1      0             0        1       1       1                0.000185
# 0      0             1        1       0       0                0.000123
#                                       1       0                0.000123
# 1      1             0        1       0       1                0.000062
#                                       1       0                0.000062
# dtype: float64

# %%
def severity(row) -> float:
    res = 0
    res += 2/10 * row["toxic"]
    res += 4/10 * row["severe_toxic"]
    res += 1/10 * row["obscene"]
    res += 1/10 * row["threat"]
    res += 1/10 * row["insult"]
    res += 1/10 * row["identity_hate"]
    return res

# %%
col = "label"
df[col] = df.progress_apply(severity, axis=1)
df[col] = df[col].astype(np.float32)
# Out:
# 100%|██████████████████████████████████████| 16225/16225 [00:00<00:00, 46221.80it/s]

# %%
df[col].describe(percentiles=percentiles)
# Out:
# count    16225.000000
# mean         0.340074
# std          0.184916
# min          0.100000
# 1%           0.100000
# 5%           0.200000
# 10%          0.200000
# 20%          0.200000
# 30%          0.200000
# 40%          0.200000
# 50%          0.300000
# 60%          0.300000
# 70%          0.400000
# 80%          0.400000
# 90%          0.600000
# 95%          0.800000
# 99%          0.900000
# max          1.000000
# Name: label, dtype: float64

# %%
# Force unique ranks
df[col] = rankdata(df[col], method='ordinal')
df[col] = df[col].astype(np.int32)
df[col].describe(percentiles=percentiles)
# Out:
# count    16225.000000
# mean      8113.000000
# std       4683.898394
# min          1.000000
# 1%         163.240000
# 5%         812.200000
# 10%       1623.400000
# 20%       3245.800000
# 30%       4868.200000
# 40%       6490.600000
# 50%       8113.000000
# 60%       9735.400000
# 70%      11357.800000
# 80%      12980.200000
# 90%      14602.600000
# 95%      15413.800000
# 99%      16062.760000
# max      16225.000000
# Name: label, dtype: float64

# %% [markdown]
# # Preprocess Text

# %%
def preprocess(row) -> str:
    res = row["comment_text"]
    res = " ".join(res.split())
    return res

# %%
col = "comment_text"
df[col] = df.progress_apply(preprocess, axis=1)
# Out:
# 100%|██████████████████████████████████████| 16225/16225 [00:00<00:00, 74770.98it/s]

# %% [markdown]
# # Embeddings

# %%
model = SentenceTransformer("pretrained/sentence-transformers/paraphrase-MiniLM-L6-v2", device=device)
model.max_seq_length = 128
sentences = list(df["comment_text"])

# %%
# %%time
em = model.encode(sentences=sentences, batch_size=256, show_progress_bar=True, convert_to_numpy=True)
print(f"em.shape={em.shape}")
# Out:
# Batches:   0%|          | 0/64 [00:00<?, ?it/s]
# em.shape=(16225, 384)
# Wall time: 21 s

# %%
# %%time
em_size = em.shape[1]
em_cols = [f"e{i}" for i in range(em_size)]
df[em_cols] = em
df[em_cols] = df[em_cols].astype(np.float32)
# avoid fragmented frame
df = df.copy()
del sentences
# Out:
# s:\dev\seahrh\kaggle-jigsaw-toxic-severity-rating\env\lib\site-packages\pandas\core\frame.py:3673: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self[col] = igetitem(value, i)
# Wall time: 299 ms

# %%
cols = ["label"]
cols += em_cols
df[cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16225 entries, 6 to 159554
# Data columns (total 385 columns):
#  #    Column  Non-Null Count  Dtype
# ---   ------  --------------  -----
#  0    label   16225 non-null  int32
#  1    e0      16225 non-null  float32
#  2    e1      16225 non-null  float32
#  3    e2      16225 non-null  float32
#  4    e3      16225 non-null  float32
#  5    e4      16225 non-null  float32
#  6    e5      16225 non-null  float32
#  7    e6      16225 non-null  float32
#  8    e7      16225 non-null  float32
#  9    e8      16225 non-null  float32
#  10   e9      16225 non-null  float32
#  11   e10     16225 non-null  float32
#  12   e11     16225 non-null  float32
#  13   e12     16225 non-null  float32
#  14   e13     16225 non-null  float32
#  15   e14     16225 non-null  float32
#  16   e15     16225 non-null  float32
#  17   e16     16225 non-null  float32
#  18   e17     16225 non-null  float32
#  19   e18     16225 non-null  float32
#  20   e19     16225 non-null  float32
#  21   e20     16225 non-null  float32
#  22   e21     16225 non-null  float32
#  23   e22     16225 non-null  float32
#  24   e23     16225 non-null  float32
#  25   e24     16225 non-null  float32
#  26   e25     16225 non-null  float32
#  27   e26     16225 non-null  float32
#  28   e27     16225 non-null  float32
#  29   e28     16225 non-null  float32
#  30   e29     16225 non-null  float32
#  31   e30     16225 non-null  float32
#  32   e31     16225 non-null  float32
#  33   e32     16225 non-null  float32
#  34   e33     16225 non-null  float32
#  35   e34     16225 non-null  float32
#  36   e35     16225 non-null  float32
#  37   e36     16225 non-null  float32
#  38   e37     16225 non-null  float32
#  39   e38     16225 non-null  float32
#  40   e39     16225 non-null  float32
#  41   e40     16225 non-null  float32
#  42   e41     16225 non-null  float32
#  43   e42     16225 non-null  float32
#  44   e43     16225 non-null  float32
#  45   e44     16225 non-null  float32
#  46   e45     16225 non-null  float32
#  47   e46     16225 non-null  float32
#  48   e47     16225 non-null  float32
#  49   e48     16225 non-null  float32
#  50   e49     16225 non-null  float32
#  51   e50     16225 non-null  float32
#  52   e51     16225 non-null  float32
#  53   e52     16225 non-null  float32
#  54   e53     16225 non-null  float32
#  55   e54     16225 non-null  float32
#  56   e55     16225 non-null  float32
#  57   e56     16225 non-null  float32
#  58   e57     16225 non-null  float32
#  59   e58     16225 non-null  float32
#  60   e59     16225 non-null  float32
#  61   e60     16225 non-null  float32
#  62   e61     16225 non-null  float32
#  63   e62     16225 non-null  float32
#  64   e63     16225 non-null  float32
#  65   e64     16225 non-null  float32
#  66   e65     16225 non-null  float32
#  67   e66     16225 non-null  float32
#  68   e67     16225 non-null  float32
#  69   e68     16225 non-null  float32
#  70   e69     16225 non-null  float32
#  71   e70     16225 non-null  float32
#  72   e71     16225 non-null  float32
#  73   e72     16225 non-null  float32
#  74   e73     16225 non-null  float32
#  75   e74     16225 non-null  float32
#  76   e75     16225 non-null  float32
#  77   e76     16225 non-null  float32
#  78   e77     16225 non-null  float32
#  79   e78     16225 non-null  float32
#  80   e79     16225 non-null  float32
#  81   e80     16225 non-null  float32
#  82   e81     16225 non-null  float32
#  83   e82     16225 non-null  float32
#  84   e83     16225 non-null  float32
#  85   e84     16225 non-null  float32
#  86   e85     16225 non-null  float32
#  87   e86     16225 non-null  float32
#  88   e87     16225 non-null  float32
#  89   e88     16225 non-null  float32
#  90   e89     16225 non-null  float32
#  91   e90     16225 non-null  float32
#  92   e91     16225 non-null  float32
#  93   e92     16225 non-null  float32
#  94   e93     16225 non-null  float32
#  95   e94     16225 non-null  float32
#  96   e95     16225 non-null  float32
#  97   e96     16225 non-null  float32
#  98   e97     16225 non-null  float32
#  99   e98     16225 non-null  float32
#  100  e99     16225 non-null  float32
#  101  e100    16225 non-null  float32
#  102  e101    16225 non-null  float32
#  103  e102    16225 non-null  float32
#  104  e103    16225 non-null  float32
#  105  e104    16225 non-null  float32
#  106  e105    16225 non-null  float32
#  107  e106    16225 non-null  float32
#  108  e107    16225 non-null  float32
#  109  e108    16225 non-null  float32
#  110  e109    16225 non-null  float32
#  111  e110    16225 non-null  float32
#  112  e111    16225 non-null  float32
#  113  e112    16225 non-null  float32
#  114  e113    16225 non-null  float32
#  115  e114    16225 non-null  float32
#  116  e115    16225 non-null  float32
#  117  e116    16225 non-null  float32
#  118  e117    16225 non-null  float32
#  119  e118    16225 non-null  float32
#  120  e119    16225 non-null  float32
#  121  e120    16225 non-null  float32
#  122  e121    16225 non-null  float32
#  123  e122    16225 non-null  float32
#  124  e123    16225 non-null  float32
#  125  e124    16225 non-null  float32
#  126  e125    16225 non-null  float32
#  127  e126    16225 non-null  float32
#  128  e127    16225 non-null  float32
#  129  e128    16225 non-null  float32
#  130  e129    16225 non-null  float32
#  131  e130    16225 non-null  float32
#  132  e131    16225 non-null  float32
#  133  e132    16225 non-null  float32
#  134  e133    16225 non-null  float32
#  135  e134    16225 non-null  float32
#  136  e135    16225 non-null  float32
#  137  e136    16225 non-null  float32
#  138  e137    16225 non-null  float32
#  139  e138    16225 non-null  float32
#  140  e139    16225 non-null  float32
#  141  e140    16225 non-null  float32
#  142  e141    16225 non-null  float32
#  143  e142    16225 non-null  float32
#  144  e143    16225 non-null  float32
#  145  e144    16225 non-null  float32
#  146  e145    16225 non-null  float32
#  147  e146    16225 non-null  float32
#  148  e147    16225 non-null  float32
#  149  e148    16225 non-null  float32
#  150  e149    16225 non-null  float32
#  151  e150    16225 non-null  float32
#  152  e151    16225 non-null  float32
#  153  e152    16225 non-null  float32
#  154  e153    16225 non-null  float32
#  155  e154    16225 non-null  float32
#  156  e155    16225 non-null  float32
#  157  e156    16225 non-null  float32
#  158  e157    16225 non-null  float32
#  159  e158    16225 non-null  float32
#  160  e159    16225 non-null  float32
#  161  e160    16225 non-null  float32
#  162  e161    16225 non-null  float32
#  163  e162    16225 non-null  float32
#  164  e163    16225 non-null  float32
#  165  e164    16225 non-null  float32
#  166  e165    16225 non-null  float32
#  167  e166    16225 non-null  float32
#  168  e167    16225 non-null  float32
#  169  e168    16225 non-null  float32
#  170  e169    16225 non-null  float32
#  171  e170    16225 non-null  float32
#  172  e171    16225 non-null  float32
#  173  e172    16225 non-null  float32
#  174  e173    16225 non-null  float32
#  175  e174    16225 non-null  float32
#  176  e175    16225 non-null  float32
#  177  e176    16225 non-null  float32
#  178  e177    16225 non-null  float32
#  179  e178    16225 non-null  float32
#  180  e179    16225 non-null  float32
#  181  e180    16225 non-null  float32
#  182  e181    16225 non-null  float32
#  183  e182    16225 non-null  float32
#  184  e183    16225 non-null  float32
#  185  e184    16225 non-null  float32
#  186  e185    16225 non-null  float32
#  187  e186    16225 non-null  float32
#  188  e187    16225 non-null  float32
#  189  e188    16225 non-null  float32
#  190  e189    16225 non-null  float32
#  191  e190    16225 non-null  float32
#  192  e191    16225 non-null  float32
#  193  e192    16225 non-null  float32
#  194  e193    16225 non-null  float32
#  195  e194    16225 non-null  float32
#  196  e195    16225 non-null  float32
#  197  e196    16225 non-null  float32
#  198  e197    16225 non-null  float32
#  199  e198    16225 non-null  float32
#  200  e199    16225 non-null  float32
#  201  e200    16225 non-null  float32
#  202  e201    16225 non-null  float32
#  203  e202    16225 non-null  float32
#  204  e203    16225 non-null  float32
#  205  e204    16225 non-null  float32
#  206  e205    16225 non-null  float32
#  207  e206    16225 non-null  float32
#  208  e207    16225 non-null  float32
#  209  e208    16225 non-null  float32
#  210  e209    16225 non-null  float32
#  211  e210    16225 non-null  float32
#  212  e211    16225 non-null  float32
#  213  e212    16225 non-null  float32
#  214  e213    16225 non-null  float32
#  215  e214    16225 non-null  float32
#  216  e215    16225 non-null  float32
#  217  e216    16225 non-null  float32
#  218  e217    16225 non-null  float32
#  219  e218    16225 non-null  float32
#  220  e219    16225 non-null  float32
#  221  e220    16225 non-null  float32
#  222  e221    16225 non-null  float32
#  223  e222    16225 non-null  float32
#  224  e223    16225 non-null  float32
#  225  e224    16225 non-null  float32
#  226  e225    16225 non-null  float32
#  227  e226    16225 non-null  float32
#  228  e227    16225 non-null  float32
#  229  e228    16225 non-null  float32
#  230  e229    16225 non-null  float32
#  231  e230    16225 non-null  float32
#  232  e231    16225 non-null  float32
#  233  e232    16225 non-null  float32
#  234  e233    16225 non-null  float32
#  235  e234    16225 non-null  float32
#  236  e235    16225 non-null  float32
#  237  e236    16225 non-null  float32
#  238  e237    16225 non-null  float32
#  239  e238    16225 non-null  float32
#  240  e239    16225 non-null  float32
#  241  e240    16225 non-null  float32
#  242  e241    16225 non-null  float32
#  243  e242    16225 non-null  float32
#  244  e243    16225 non-null  float32
#  245  e244    16225 non-null  float32
#  246  e245    16225 non-null  float32
#  247  e246    16225 non-null  float32
#  248  e247    16225 non-null  float32
#  249  e248    16225 non-null  float32
#  250  e249    16225 non-null  float32
#  251  e250    16225 non-null  float32
#  252  e251    16225 non-null  float32
#  253  e252    16225 non-null  float32
#  254  e253    16225 non-null  float32
#  255  e254    16225 non-null  float32
#  256  e255    16225 non-null  float32
#  257  e256    16225 non-null  float32
#  258  e257    16225 non-null  float32
#  259  e258    16225 non-null  float32
#  260  e259    16225 non-null  float32
#  261  e260    16225 non-null  float32
#  262  e261    16225 non-null  float32
#  263  e262    16225 non-null  float32
#  264  e263    16225 non-null  float32
#  265  e264    16225 non-null  float32
#  266  e265    16225 non-null  float32
#  267  e266    16225 non-null  float32
#  268  e267    16225 non-null  float32
#  269  e268    16225 non-null  float32
#  270  e269    16225 non-null  float32
#  271  e270    16225 non-null  float32
#  272  e271    16225 non-null  float32
#  273  e272    16225 non-null  float32
#  274  e273    16225 non-null  float32
#  275  e274    16225 non-null  float32
#  276  e275    16225 non-null  float32
#  277  e276    16225 non-null  float32
#  278  e277    16225 non-null  float32
#  279  e278    16225 non-null  float32
#  280  e279    16225 non-null  float32
#  281  e280    16225 non-null  float32
#  282  e281    16225 non-null  float32
#  283  e282    16225 non-null  float32
#  284  e283    16225 non-null  float32
#  285  e284    16225 non-null  float32
#  286  e285    16225 non-null  float32
#  287  e286    16225 non-null  float32
#  288  e287    16225 non-null  float32
#  289  e288    16225 non-null  float32
#  290  e289    16225 non-null  float32
#  291  e290    16225 non-null  float32
#  292  e291    16225 non-null  float32
#  293  e292    16225 non-null  float32
#  294  e293    16225 non-null  float32
#  295  e294    16225 non-null  float32
#  296  e295    16225 non-null  float32
#  297  e296    16225 non-null  float32
#  298  e297    16225 non-null  float32
#  299  e298    16225 non-null  float32
#  300  e299    16225 non-null  float32
#  301  e300    16225 non-null  float32
#  302  e301    16225 non-null  float32
#  303  e302    16225 non-null  float32
#  304  e303    16225 non-null  float32
#  305  e304    16225 non-null  float32
#  306  e305    16225 non-null  float32
#  307  e306    16225 non-null  float32
#  308  e307    16225 non-null  float32
#  309  e308    16225 non-null  float32
#  310  e309    16225 non-null  float32
#  311  e310    16225 non-null  float32
#  312  e311    16225 non-null  float32
#  313  e312    16225 non-null  float32
#  314  e313    16225 non-null  float32
#  315  e314    16225 non-null  float32
#  316  e315    16225 non-null  float32
#  317  e316    16225 non-null  float32
#  318  e317    16225 non-null  float32
#  319  e318    16225 non-null  float32
#  320  e319    16225 non-null  float32
#  321  e320    16225 non-null  float32
#  322  e321    16225 non-null  float32
#  323  e322    16225 non-null  float32
#  324  e323    16225 non-null  float32
#  325  e324    16225 non-null  float32
#  326  e325    16225 non-null  float32
#  327  e326    16225 non-null  float32
#  328  e327    16225 non-null  float32
#  329  e328    16225 non-null  float32
#  330  e329    16225 non-null  float32
#  331  e330    16225 non-null  float32
#  332  e331    16225 non-null  float32
#  333  e332    16225 non-null  float32
#  334  e333    16225 non-null  float32
#  335  e334    16225 non-null  float32
#  336  e335    16225 non-null  float32
#  337  e336    16225 non-null  float32
#  338  e337    16225 non-null  float32
#  339  e338    16225 non-null  float32
#  340  e339    16225 non-null  float32
#  341  e340    16225 non-null  float32
#  342  e341    16225 non-null  float32
#  343  e342    16225 non-null  float32
#  344  e343    16225 non-null  float32
#  345  e344    16225 non-null  float32
#  346  e345    16225 non-null  float32
#  347  e346    16225 non-null  float32
#  348  e347    16225 non-null  float32
#  349  e348    16225 non-null  float32
#  350  e349    16225 non-null  float32
#  351  e350    16225 non-null  float32
#  352  e351    16225 non-null  float32
#  353  e352    16225 non-null  float32
#  354  e353    16225 non-null  float32
#  355  e354    16225 non-null  float32
#  356  e355    16225 non-null  float32
#  357  e356    16225 non-null  float32
#  358  e357    16225 non-null  float32
#  359  e358    16225 non-null  float32
#  360  e359    16225 non-null  float32
#  361  e360    16225 non-null  float32
#  362  e361    16225 non-null  float32
#  363  e362    16225 non-null  float32
#  364  e363    16225 non-null  float32
#  365  e364    16225 non-null  float32
#  366  e365    16225 non-null  float32
#  367  e366    16225 non-null  float32
#  368  e367    16225 non-null  float32
#  369  e368    16225 non-null  float32
#  370  e369    16225 non-null  float32
#  371  e370    16225 non-null  float32
#  372  e371    16225 non-null  float32
#  373  e372    16225 non-null  float32
#  374  e373    16225 non-null  float32
#  375  e374    16225 non-null  float32
#  376  e375    16225 non-null  float32
#  377  e376    16225 non-null  float32
#  378  e377    16225 non-null  float32
#  379  e378    16225 non-null  float32
#  380  e379    16225 non-null  float32
#  381  e380    16225 non-null  float32
#  382  e381    16225 non-null  float32
#  383  e382    16225 non-null  float32
#  384  e383    16225 non-null  float32
# dtypes: float32(384), int32(1)
# memory usage: 24.0 MB

# %%
# %%time
df[cols].to_parquet("output/js18.parquet", index=False)
# Out:
# Wall time: 469 ms
