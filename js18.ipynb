# %%
import os
import numpy as np
import pandas as pd
import torch
from sentence_transformers import SentenceTransformer
from scipy.stats import rankdata
from tqdm import tqdm
import scml

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda
# NVIDIA GeForce GTX 1060 6GB
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB

# %%
percentiles=[.01, .05, .1, .2, .3, .4, .5, .6, .7, .8, .9, .95, .99]
os.environ["TOKENIZERS_PARALLELISM"] = "false"
pd.set_option("use_inf_as_na", True)
pd.set_option("max_info_columns", 9999)
pd.set_option("display.max_columns", 9999)
pd.set_option("display.max_rows", 9999)
pd.set_option('max_colwidth', 9999)
tqdm.pandas()

# %%
# %%time
df = pd.read_csv("input/js18/train.csv", engine="c", low_memory=False)
df.drop(columns=["id"], inplace=True)
cols = ["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]
df[cols] = df[cols].astype(np.int8) 
df["label_sum"] = df["toxic"] + df["severe_toxic"] + df["obscene"] + df["threat"] + df["insult"] + df["identity_hate"]
df.drop(index=df[df.label_sum == 0].index, inplace=True)
df.drop(columns=["label_sum"], inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16225 entries, 6 to 159554
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   comment_text   16225 non-null  object
#  1   toxic          16225 non-null  int8
#  2   severe_toxic   16225 non-null  int8
#  3   obscene        16225 non-null  int8
#  4   threat         16225 non-null  int8
#  5   insult         16225 non-null  int8
#  6   identity_hate  16225 non-null  int8
# dtypes: int8(6), object(1)
# memory usage: 348.6+ KB
# Wall time: 927 ms

# %%
scml.find_missing_values(df)
# Out:
#                Total  Percent    Type
# comment_text       0      0.0  object
# toxic              0      0.0    int8
# severe_toxic       0      0.0    int8
# obscene            0      0.0    int8
# threat             0      0.0    int8
# insult             0      0.0    int8
# identity_hate      0      0.0    int8

# %%
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               comment_text  \
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             COCKSUCKER BEFORE YOU PISS AROUND ON MY WORK
# 12                                                                                                                                                                                                                                                                                                                                                     Hey... what is it..\n@ | talk .\nWhat is it... an exclusive group of some WP TALIBANS...who are good at destroying, self-appointed purist who GANG UP any one who asks them questions abt their ANTI-SOCIAL and DESTRUCTIVE (non)-contribution at WP?\n\nAsk Sityush to clean up his behavior than issue me nonsensical warnings...
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Bye! \n\nDon't look, come or think of comming back! Tosser.
# 42  You are gay or antisemmitian? \n\nArchangel WHite Tiger\n\nMeow! Greetingshhh!\n\nUh, there are two ways, why you do erased my comment about WW2, that holocaust was brutally slaying of Jews and not gays/Gypsys/Slavs/anyone...\n\n1 - If you are anti-semitian, than shave your head bald and go to the skinhead meetings!\n\n2 - If you doubt words of the Bible, that homosexuality is a deadly sin, make a pentagram tatoo on your forehead go to the satanistic masses with your gay pals!\n\n3 - First and last warning, you fucking gay - I won't appreciate if any more nazi shwain would write in my page! I don't wish to talk to you anymore!\n\nBeware of the Dark Side!
# 43                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                FUCK YOUR FILTHY MOTHER IN THE ASS, DRY!
#
#     toxic  severe_toxic  obscene  threat  insult  identity_hate
# 6       1             1        1       0       1              0
# 12      1             0        0       0       0              0
# 16      1             0        0       0       0              0
# 42      1             0        1       0       1              1
# 43      1             0        1       0       1              0

# %% [markdown]
# # Severity rating label

# %%
df[cols].value_counts(normalize=True)
# Out:
# toxic  severe_toxic  obscene  threat  insult  identity_hate
# 1      0             0        0       0       0                0.349214
#                      1        0       1       0                0.234206
#                                       0       0                0.108351
#                      0        0       1       0                0.074884
#        1             1        0       1       0                0.060955
#        0             1        0       1       1                0.038089
# 0      0             1        0       0       0                0.019538
#                      0        0       1       0                0.018552
# 1      1             1        0       1       1                0.016333
# 0      0             1        0       1       0                0.011156
# 1      1             1        0       0       0                0.009738
#        0             0        0       0       1                0.008382
#                                       1       1                0.008259
#                      1        1       1       0                0.008074
#                      0        1       0       0                0.006965
#        1             1        1       1       0                0.003945
#        0             1        1       1       1                0.003451
# 0      0             0        0       0       1                0.003328
# 1      1             0        0       0       0                0.002527
#        0             1        0       0       1                0.002157
#        1             1        1       1       1                0.001911
# 0      0             0        0       1       1                0.001726
#                               1       0       0                0.001356
#                      1        0       1       1                0.001109
# 1      0             0        1       1       0                0.000986
#        1             0        0       1       0                0.000863
#                               1       0       0                0.000678
#        0             1        1       0       0                0.000678
#        1             0        0       1       1                0.000431
#        0             0        1       0       1                0.000431
#        1             1        0       0       1                0.000370
#                               1       0       0                0.000247
#                      0        0       0       1                0.000185
# 0      0             1        0       0       1                0.000185
#                      0        1       1       0                0.000185
# 1      0             0        1       1       1                0.000185
# 0      0             1        1       0       0                0.000123
#                                       1       0                0.000123
# 1      1             0        1       0       1                0.000062
#                                       1       0                0.000062
# dtype: float64

# %%
def severity(row) -> float:
    res = 0
    res += 2/10 * row["toxic"]
    res += 4/10 * row["severe_toxic"]
    res += 1/10 * row["obscene"]
    res += 1/10 * row["threat"]
    res += 1/10 * row["insult"]
    res += 1/10 * row["identity_hate"]
    return res

# %%
col = "label"
df[col] = df.progress_apply(severity, axis=1)
df[col] = df[col].astype(np.float32)
# Out:
# 100%|██████████████████████████████████████| 16225/16225 [00:00<00:00, 45064.65it/s]

# %%
df[col].describe(percentiles=percentiles)
# Out:
# count    16225.000000
# mean         0.340074
# std          0.184916
# min          0.100000
# 1%           0.100000
# 5%           0.200000
# 10%          0.200000
# 20%          0.200000
# 30%          0.200000
# 40%          0.200000
# 50%          0.300000
# 60%          0.300000
# 70%          0.400000
# 80%          0.400000
# 90%          0.600000
# 95%          0.800000
# 99%          0.900000
# max          1.000000
# Name: label, dtype: float64

# %%
# Force unique ranks
df[col] = rankdata(df[col], method='ordinal')
df[col] = df[col].astype(np.int32)
df[col].describe(percentiles=percentiles)
# Out:
# count    16225.000000
# mean      8113.000000
# std       4683.898394
# min          1.000000
# 1%         163.240000
# 5%         812.200000
# 10%       1623.400000
# 20%       3245.800000
# 30%       4868.200000
# 40%       6490.600000
# 50%       8113.000000
# 60%       9735.400000
# 70%      11357.800000
# 80%      12980.200000
# 90%      14602.600000
# 95%      15413.800000
# 99%      16062.760000
# max      16225.000000
# Name: label, dtype: float64

# %% [markdown]
# # Preprocess Text

# %%
def preprocess(row) -> str:
    res = row["comment_text"]
    res = " ".join(res.split())
    return res

# %%
col = "comment_text"
df[col] = df.progress_apply(preprocess, axis=1)
# Out:
# 100%|██████████████████████████████████████| 16225/16225 [00:00<00:00, 75473.01it/s]

# %% [markdown]
# # Embeddings

# %%
model = SentenceTransformer("pretrained/sentence-transformers/paraphrase-MiniLM-L6-v2", device=device)
model.max_seq_length = 128
sentences = list(df["comment_text"])

# %%
# %%time
em = model.encode(sentences=sentences, batch_size=1000, show_progress_bar=True, convert_to_numpy=True)
print(f"em.shape={em.shape}")
# Out:
# Batches:   0%|          | 0/17 [00:00<?, ?it/s]
# em.shape=(16225, 384)
# Wall time: 23.1 s

# %%
# %%time
em_size = em.shape[1]
em_cols = [f"zz{i:04d}" for i in range(em_size)]
df[em_cols] = em
df[em_cols] = df[em_cols].astype(np.float32)
# avoid fragmented frame
df = df.copy()
del sentences
# Out:
# s:\dev\seahrh\kaggle-jigsaw-toxic-severity-rating\env\lib\site-packages\pandas\core\frame.py:3673: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self[col] = igetitem(value, i)
# Wall time: 314 ms

# %%
cols = ["label"]
cols += em_cols
df[cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16225 entries, 6 to 159554
# Data columns (total 385 columns):
#  #    Column  Non-Null Count  Dtype
# ---   ------  --------------  -----
#  0    label   16225 non-null  int32
#  1    zz0000  16225 non-null  float32
#  2    zz0001  16225 non-null  float32
#  3    zz0002  16225 non-null  float32
#  4    zz0003  16225 non-null  float32
#  5    zz0004  16225 non-null  float32
#  6    zz0005  16225 non-null  float32
#  7    zz0006  16225 non-null  float32
#  8    zz0007  16225 non-null  float32
#  9    zz0008  16225 non-null  float32
#  10   zz0009  16225 non-null  float32
#  11   zz0010  16225 non-null  float32
#  12   zz0011  16225 non-null  float32
#  13   zz0012  16225 non-null  float32
#  14   zz0013  16225 non-null  float32
#  15   zz0014  16225 non-null  float32
#  16   zz0015  16225 non-null  float32
#  17   zz0016  16225 non-null  float32
#  18   zz0017  16225 non-null  float32
#  19   zz0018  16225 non-null  float32
#  20   zz0019  16225 non-null  float32
#  21   zz0020  16225 non-null  float32
#  22   zz0021  16225 non-null  float32
#  23   zz0022  16225 non-null  float32
#  24   zz0023  16225 non-null  float32
#  25   zz0024  16225 non-null  float32
#  26   zz0025  16225 non-null  float32
#  27   zz0026  16225 non-null  float32
#  28   zz0027  16225 non-null  float32
#  29   zz0028  16225 non-null  float32
#  30   zz0029  16225 non-null  float32
#  31   zz0030  16225 non-null  float32
#  32   zz0031  16225 non-null  float32
#  33   zz0032  16225 non-null  float32
#  34   zz0033  16225 non-null  float32
#  35   zz0034  16225 non-null  float32
#  36   zz0035  16225 non-null  float32
#  37   zz0036  16225 non-null  float32
#  38   zz0037  16225 non-null  float32
#  39   zz0038  16225 non-null  float32
#  40   zz0039  16225 non-null  float32
#  41   zz0040  16225 non-null  float32
#  42   zz0041  16225 non-null  float32
#  43   zz0042  16225 non-null  float32
#  44   zz0043  16225 non-null  float32
#  45   zz0044  16225 non-null  float32
#  46   zz0045  16225 non-null  float32
#  47   zz0046  16225 non-null  float32
#  48   zz0047  16225 non-null  float32
#  49   zz0048  16225 non-null  float32
#  50   zz0049  16225 non-null  float32
#  51   zz0050  16225 non-null  float32
#  52   zz0051  16225 non-null  float32
#  53   zz0052  16225 non-null  float32
#  54   zz0053  16225 non-null  float32
#  55   zz0054  16225 non-null  float32
#  56   zz0055  16225 non-null  float32
#  57   zz0056  16225 non-null  float32
#  58   zz0057  16225 non-null  float32
#  59   zz0058  16225 non-null  float32
#  60   zz0059  16225 non-null  float32
#  61   zz0060  16225 non-null  float32
#  62   zz0061  16225 non-null  float32
